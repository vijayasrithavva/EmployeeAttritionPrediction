# %% [markdown]
# <a href="https://colab.research.google.com/github/vijayasrithavva/EmployeeAttritionPrediction/blob/main/EmployeeAttritionPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# #Data Extraction

# %%
attrition_data = pd.read_csv('/content/WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
attrition_data.head()
# Out:
#    Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41       Yes  ...                       0                     5
# 1   49        No  ...                       1                     7
# 2   37       Yes  ...                       0                     0
# 3   33        No  ...                       3                     0
# 4   27        No  ...                       2                     2
#
# [5 rows x 35 columns]

# %%
attrition_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
attrition_data.shape
# Out:
# (1470, 35)

# %%
attrition_data.describe()
# Out:
#                Age    DailyRate  ...  YearsSinceLastPromotion  YearsWithCurrManager
# count  1470.000000  1470.000000  ...              1470.000000           1470.000000
# mean     36.923810   802.485714  ...                 2.187755              4.123129
# std       9.135373   403.509100  ...                 3.222430              3.568136
# min      18.000000   102.000000  ...                 0.000000              0.000000
# 25%      30.000000   465.000000  ...                 0.000000              2.000000
# 50%      36.000000   802.000000  ...                 1.000000              3.000000
# 75%      43.000000  1157.000000  ...                 3.000000              7.000000
# max      60.000000  1499.000000  ...                15.000000             17.000000
#
# [8 rows x 26 columns]

# %%
attrition_data['Attrition'].value_counts()
attrition_value = list(set(attrition_data['Attrition'].values))
attrition_count = list(attrition_data['Attrition'].value_counts())
print(attrition_count, attrition_value)
# Out:
# [1233, 237] ['No', 'Yes']

# %%
plt.bar(attrition_value, attrition_count)
plt.show()
plt.close()

# %%
attrition_data['Attrition'] = attrition_data['Attrition'].map({'No': 0, 'Yes': 1})
attrition_data.head()
# Out:
#    Age  Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41          1  ...                       0                     5
# 1   49          0  ...                       1                     7
# 2   37          1  ...                       0                     0
# 3   33          0  ...                       3                     0
# 4   27          0  ...                       2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# #Visualization

# %%
plt.subplots(figsize= (12, 4))
sns.countplot(x = "Age", hue = "Attrition", data = attrition_data)
plt.show()
plt.close()
sns.countplot()

# %%
plt.subplots(figsize= (12, 4))
sns.countplot(x = "BusinessTravel", hue = "Attrition", data = attrition_data)
plt.show()
plt.close()

# %%
plt.subplots(figsize= (12, 4))
sns.countplot(x = "DistanceFromHome", hue = "Attrition", data = attrition_data)
plt.show()
plt.close()

# %%
plt.subplots(figsize= (12, 4))
sns.countplot(x = "JobLevel", hue = "Attrition", data = attrition_data)
plt.show()
plt.close()

# %%
print(attrition_data['Over18'].value_counts())
print(attrition_data['EmployeeCount'].value_counts())
print(attrition_data['EmployeeNumber'].value_counts())
print(attrition_data['StandardHours'].value_counts()
# Out:
# Y    1470
# Name: Over18, dtype: int64
# 1    1470
# Name: EmployeeCount, dtype: int64
# 2046    1
# 641     1
# 644     1
# 645     1
# 647     1
#        ..
# 1364    1
# 1367    1
# 1368    1
# 1369    1
# 2048    1
# Name: EmployeeNumber, Length: 1470, dtype: int64
# 80    1470
# Name: StandardHours, dtype: int64

# %%
attrition_data = attrition_data.drop(['Over18', 'EmployeeCount', 'EmployeeNumber', 'StandardHours'], axis = 1)
attrition_data.head()
# Out:
#    Age  Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41          1  ...                       0                     5
# 1   49          0  ...                       1                     7
# 2   37          1  ...                       0                     0
# 3   33          0  ...                       3                     0
# 4   27          0  ...                       2                     2
#
# [5 rows x 31 columns]

# %%
AgeYears = attrition_data['Age']
attrition_data = attrition_data.drop(['Age'], axis = 1)

# %%
attrition_data = pd.concat([attrition_data, AgeYears], axis = 1)
attrition_data.head()
# Out:
#    Attrition     BusinessTravel  ...  YearsWithCurrManager Age
# 0          1      Travel_Rarely  ...                     5  41
# 1          0  Travel_Frequently  ...                     7  49
# 2          1      Travel_Rarely  ...                     0  37
# 3          0  Travel_Frequently  ...                     0  33
# 4          0      Travel_Rarely  ...                     2  27
#
# [5 rows x 31 columns]

# %%
attrition_data.shape
# Out:
# (1470, 31)

# %%
attrition_data.corr()
# Out:
#                           Attrition  DailyRate  ...  YearsWithCurrManager       Age
# Attrition                  1.000000  -0.056652  ...             -0.156199 -0.159205
# DailyRate                 -0.056652   1.000000  ...             -0.026363  0.010661
# DistanceFromHome           0.077924  -0.004985  ...              0.014406 -0.001686
# Education                 -0.031373  -0.016806  ...              0.069065  0.208034
# EnvironmentSatisfaction   -0.103369   0.018355  ...             -0.004999  0.010146
# HourlyRate                -0.006846   0.023381  ...             -0.020123  0.024287
# JobInvolvement            -0.130016   0.046135  ...              0.025976  0.029820
# JobLevel                  -0.169105   0.002966  ...              0.375281  0.509604
# JobSatisfaction           -0.103481   0.030571  ...             -0.027656 -0.004892
# MonthlyIncome             -0.159840   0.007707  ...              0.344079  0.497855
# ...

# %%
plt.figure(figsize= (20, 20))
sns.heatmap(attrition_data.corr(), annot=True, fmt = '.0%')
plt.show()
plt.close()

# %% [markdown]
# #Data Preprocessing

# %%
#Label encoding
from sklearn.preprocessing import LabelEncoder as le
for col in attrition_data.columns:
  if attrition_data[col].dtype == 'int64':
    continue
  else:
    attrition_data[col] = le().fit_transform(attrition_data[col])

# %%
attrition_data.head()
# Out:
#    Attrition  BusinessTravel  ...  YearsWithCurrManager  Age
# 0          1               2  ...                     5   41
# 1          0               1  ...                     7   49
# 2          1               2  ...                     0   37
# 3          0               1  ...                     0   33
# 4          0               2  ...                     2   27
#
# [5 rows x 31 columns]
